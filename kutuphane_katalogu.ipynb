# %% [markdown]
# <a href="https://colab.research.google.com/github/gizemzeynep/BBY162-2020/blob/master/kutuphane_katalogu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/gdrive')
dosya = "/gdrive/My Drive/Colab Notebooks/BBY162-2020/veritabani.txt"
print("------------------KATALOĞUMA HOŞ GELDİNİZ------------------ \n")


f = open(dosya, 'a') # Mevcut veriye ek veri yazılması için parametre: 'a'
f.write("\n") # Her yeni verinin bir alt satıra yazdırılması "test\n"


def kitap_ekle():
     kitap_adi=input("Kitap Adını Giriniz: ")
     f.write(kitap_adi+ " | " )
     yazar_adi=input("Yazar Adını Giriniz: ")
     f.write(yazar_adi+ " | " )
     basim_yili=input("Basım Yılını Giriniz: ")
     f.write(basim_yili+ " | " )
     isbn_no=input("ISBN Numarasını Giriniz: ")
     f.write(isbn_no+ " | " )
     yayin_evi=input("Yayın Evinin Adını Giriniz: " )
     f.write(yayin_evi+ " | " )

     print("Ekleme Yaptığınız Kitap Bilgileri: ", kitap_adi,"," ,yazar_adi,"," ,basim_yili,"," , isbn_no, "," ,yayin_evi)







i=0
while i<1:

    komut=input("""Hangi işlemi Yapmak İstiyorsunuz?:
    1-Kitap Ekleme
    2-Kitap Listeleme
    3-Kitap Arama
    4-Çıkış: \n""")
    if (komut=="1"):
                kitap_ekle()
                karar=input("Başka işlem yapmak isterseniz 'E' tuşuna basınız. \n")
                if(karar=="e"):
                    continue
                else:
                    break
    elif(komut=="2"):
      f = open(dosya, 'r')
      print(f.read())

    elif(komut=="3"):
      dosya = open("/gdrive/My Drive/Colab Notebooks/BBY162-2020/veritabani.txt", "r")
      aranan= input("Lütfen kitabın adını giriniz: ")
      if aranan in dosya:
        print("Kütüphanede", aranan, "'ı var!")

      karar=input("Başka işlem yapmak isterseniz 'E' tuşuna basınız. \n")
      if(karar=="e"):
          continue
      else:
          break

    elif(komut=="4"):
        i=i+1
        break
f.close()
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# ------------------KATALOĞUMA HOŞ GELDİNİZ------------------
#
# Hangi işlemi Yapmak İstiyorsunuz?:
#     1-Kitap Ekleme
#     2-Kitap Listeleme
#     3-Kitap Arama
#     4-Çıkış:
# 1
# Kitap Adını Giriniz: Daha
# Yazar Adını Giriniz: Hakan Günday
# Basım Yılını Giriniz: 2013
# ISBN Numarasını Giriniz: 42624125
# Yayın Evinin Adını Giriniz: Doğan
# Ekleme Yaptığınız Kitap Bilgileri:  Daha , Hakan Günday , 2013 , 42624125 , Doğan
# Başka işlem yapmak isterseniz 'E' tuşuna basınız.
# e
# Hangi işlemi Yapmak İstiyorsunuz?:
#     1-Kitap Ekleme
#     2-Kitap Listeleme
#     3-Kitap Arama
#     4-Çıkış:
# 2
# |Kitap Adı | Yazar Adı | ISBN Numarası | Basım Yılı | Yayınevi|
# --------------------------------------------------------------
# Masumiyet Müzesi | Orhan Pamuk| 12582052 | 2005 | Can kitapevi
# Beyaz Geceler | Fyodor Dostoyevski | 7856412 | 2000 | YYK
# ...
